# %%
import json

import numpy as np

# %%
clusters = json.load(open("/home/fbelotti/group-sae/training/pythia-410m.json"))

# %%
training_clusters = clusters.pop("training_clusters")

# %%
clusters_grouped = {}
for cluster in clusters:
    labels = clusters[cluster]["labels"]
    layers_grouped = [[] for _ in range(len(np.unique(labels)))]
    layer_idx = 0
    group_index = 0
    last_label = labels[0]
    layers_grouped[0].append(str(layer_idx))
    for label in labels[1:]:
        layer_idx += 1
        if label != last_label:
            group_index += 1
            layers_grouped[group_index].append(str(layer_idx))
            last_label = label
        else:
            layers_grouped[group_index].append(str(layer_idx))
    clusters_grouped[cluster] = layers_grouped

# %%
clusters_to_saes = {}
for cluster in clusters_grouped:
    saes = []
    for group in clusters_grouped[cluster]:
        if len(group) == 1:
            saes.extend([f"layers.{group[0]}"])
        for cluster_name, layers in training_clusters.items():
            if group == layers:
                saes.extend([cluster_name for _ in range(len(layers))])
                break
    clusters_to_saes[cluster] = saes

# %%
for cluster, saes in clusters_to_saes.items():
    print(f"Cluster {cluster} is assigned to SAEs {saes}")
# Out:
# Cluster 1 is assigned to SAEs ['k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0', 'k1-c0']
# Cluster 2 is assigned to SAEs ['k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c0', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1']
# Cluster 3 is assigned to SAEs ['k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c0', 'k3-c0', 'k3-c0', 'k3-c0', 'k3-c0', 'k3-c0', 'k3-c0', 'k3-c0', 'k3-c0', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1']
# Cluster 4 is assigned to SAEs ['k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c0', 'k4-c0', 'k4-c0', 'k4-c0', 'k4-c0', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1', 'k2-c1']
# Cluster 5 is assigned to SAEs ['k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k3-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c0', 'k4-c0', 'k4-c0', 'k4-c0', 'k4-c0', 'k5-c1', 'k5-c1', 'k5-c1', 'k5-c0', 'k5-c0', 'k5-c0', 'k5-c0']
# Cluster 6 is assigned to SAEs ['k6-c1', 'k6-c1', 'k6-c1', 'k6-c0', 'k6-c0', 'k6-c0', 'k6-c0', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c0', 'k4-c0', 'k4-c0', 'k4-c0', 'k4-c0', 'k5-c1', 'k5-c1', 'k5-c1', 'k5-c0', 'k5-c0', 'k5-c0', 'k5-c0']
# Cluster 7 is assigned to SAEs ['k6-c1', 'k6-c1', 'k6-c1', 'k6-c0', 'k6-c0', 'k6-c0', 'k6-c0', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k7-c1', 'k7-c1', 'k7-c0', 'k7-c0', 'k7-c0', 'k5-c1', 'k5-c1', 'k5-c1', 'k5-c0', 'k5-c0', 'k5-c0', 'k5-c0']
# Cluster 8 is assigned to SAEs ['k6-c1', 'k6-c1', 'k6-c1', 'k8-c0', 'k8-c0', 'k8-c1', 'k8-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k7-c1', 'k7-c1', 'k7-c0', 'k7-c0', 'k7-c0', 'k5-c1', 'k5-c1', 'k5-c1', 'k5-c0', 'k5-c0', 'k5-c0', 'k5-c0']
# Cluster 9 is assigned to SAEs ['k6-c1', 'k6-c1', 'k6-c1', 'k8-c0', 'k8-c0', 'k8-c1', 'k8-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k4-c1', 'k7-c1', 'k7-c1', 'k7-c0', 'k7-c0', 'k7-c0', 'k5-c1', 'k5-c1', 'k5-c1', 'k9-c1', 'k9-c1', 'k9-c0', 'k9-c0']
# Cluster 10 is assigned to SAEs ['k6-c1', 'k6-c1', 'k6-c1', 'k8-c0', 'k8-c0', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'k7-c0', 'k7-c0', 'k7-c0', 'k5-c1', 'k5-c1', 'k5-c1', 'k9-c1', 'k9-c1', 'k9-c0', 'k9-c0']
# Cluster 11 is assigned to SAEs ['k6-c1', 'k6-c1', 'k6-c1', 'k8-c0', 'k8-c0', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'k7-c0', 'k7-c0', 'k7-c0', 'layers.16', 'k11-c0', 'k11-c0', 'k9-c1', 'k9-c1', 'k9-c0', 'k9-c0']
# Cluster 12 is assigned to SAEs ['k6-c1', 'k6-c1', 'k6-c1', 'k8-c0', 'k8-c0', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'k11-c0', 'k11-c0', 'k9-c1', 'k9-c1', 'k9-c0', 'k9-c0']
# Cluster 13 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'k8-c0', 'k8-c0', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'k11-c0', 'k11-c0', 'k9-c1', 'k9-c1', 'k9-c0', 'k9-c0']
# Cluster 14 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'k8-c0', 'k8-c0', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'k11-c0', 'k11-c0', 'k9-c1', 'k9-c1', 'layers.21', 'layers.22']
# Cluster 15 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'k11-c0', 'k11-c0', 'k9-c1', 'k9-c1', 'layers.21', 'layers.22']
# Cluster 16 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'layers.17', 'layers.18', 'k9-c1', 'k9-c1', 'layers.21', 'layers.22']
# Cluster 17 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'k8-c1', 'k8-c1', 'k10-c0', 'k10-c0', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'layers.17', 'layers.18', 'layers.19', 'layers.20', 'layers.21', 'layers.22']
# Cluster 18 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'k8-c1', 'k8-c1', 'layers.7', 'layers.8', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'layers.17', 'layers.18', 'layers.19', 'layers.20', 'layers.21', 'layers.22']
# Cluster 19 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'layers.5', 'layers.6', 'layers.7', 'layers.8', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'k12-c0', 'k12-c0', 'layers.16', 'layers.17', 'layers.18', 'layers.19', 'layers.20', 'layers.21', 'layers.22']
# Cluster 20 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'layers.5', 'layers.6', 'layers.7', 'layers.8', 'k10-c1', 'k10-c1', 'k7-c1', 'k7-c1', 'layers.13', 'layers.14', 'layers.15', 'layers.16', 'layers.17', 'layers.18', 'layers.19', 'layers.20', 'layers.21', 'layers.22']
# Cluster 21 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'layers.5', 'layers.6', 'layers.7', 'layers.8', 'layers.9', 'layers.10', 'k7-c1', 'k7-c1', 'layers.13', 'layers.14', 'layers.15', 'layers.16', 'layers.17', 'layers.18', 'layers.19', 'layers.20', 'layers.21', 'layers.22']
# Cluster 22 is assigned to SAEs ['layers.0', 'k13-c0', 'k13-c0', 'layers.3', 'layers.4', 'layers.5', 'layers.6', 'layers.7', 'layers.8', 'layers.9', 'layers.10', 'layers.11', 'layers.12', 'layers.13', 'layers.14', 'layers.15', 'layers.16', 'layers.17', 'layers.18', 'layers.19', 'layers.20', 'layers.21', 'layers.22']

# %%
clusters_to_saes
# Out:
# {'1': ['k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0',
#   'k1-c0'],
#  '2': ['k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c0',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1'],
#  '3': ['k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c0',
#   'k3-c0',
#   'k3-c0',
#   'k3-c0',
#   'k3-c0',
#   'k3-c0',
#   'k3-c0',
#   'k3-c0',
#   'k3-c0',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1'],
#  '4': ['k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1',
#   'k2-c1'],
#  '5': ['k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k3-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k5-c1',
#   'k5-c1',
#   'k5-c1',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0'],
#  '6': ['k6-c1',
#   'k6-c1',
#   'k6-c1',
#   'k6-c0',
#   'k6-c0',
#   'k6-c0',
#   'k6-c0',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k4-c0',
#   'k5-c1',
#   'k5-c1',
#   'k5-c1',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0'],
#  '7': ['k6-c1',
#   'k6-c1',
#   'k6-c1',
#   'k6-c0',
#   'k6-c0',
#   'k6-c0',
#   'k6-c0',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k7-c1',
#   'k7-c1',
#   'k7-c0',
#   'k7-c0',
#   'k7-c0',
#   'k5-c1',
#   'k5-c1',
#   'k5-c1',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0'],
#  '8': ['k6-c1',
#   'k6-c1',
#   'k6-c1',
#   'k8-c0',
#   'k8-c0',
#   'k8-c1',
#   'k8-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k7-c1',
#   'k7-c1',
#   'k7-c0',
#   'k7-c0',
#   'k7-c0',
#   'k5-c1',
#   'k5-c1',
#   'k5-c1',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0',
#   'k5-c0'],
#  '9': ['k6-c1',
#   'k6-c1',
#   'k6-c1',
#   'k8-c0',
#   'k8-c0',
#   'k8-c1',
#   'k8-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k4-c1',
#   'k7-c1',
#   'k7-c1',
#   'k7-c0',
#   'k7-c0',
#   'k7-c0',
#   'k5-c1',
#   'k5-c1',
#   'k5-c1',
#   'k9-c1',
#   'k9-c1',
#   'k9-c0',
#   'k9-c0'],
#  '10': ['k6-c1',
#   'k6-c1',
#   'k6-c1',
#   'k8-c0',
#   'k8-c0',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'k7-c0',
#   'k7-c0',
#   'k7-c0',
#   'k5-c1',
#   'k5-c1',
#   'k5-c1',
#   'k9-c1',
#   'k9-c1',
#   'k9-c0',
#   'k9-c0'],
#  '11': ['k6-c1',
#   'k6-c1',
#   'k6-c1',
#   'k8-c0',
#   'k8-c0',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'k7-c0',
#   'k7-c0',
#   'k7-c0',
#   'layers.16',
#   'k11-c0',
#   'k11-c0',
#   'k9-c1',
#   'k9-c1',
#   'k9-c0',
#   'k9-c0'],
#  '12': ['k6-c1',
#   'k6-c1',
#   'k6-c1',
#   'k8-c0',
#   'k8-c0',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'k11-c0',
#   'k11-c0',
#   'k9-c1',
#   'k9-c1',
#   'k9-c0',
#   'k9-c0'],
#  '13': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'k8-c0',
#   'k8-c0',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'k11-c0',
#   'k11-c0',
#   'k9-c1',
#   'k9-c1',
#   'k9-c0',
#   'k9-c0'],
#  '14': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'k8-c0',
#   'k8-c0',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'k11-c0',
#   'k11-c0',
#   'k9-c1',
#   'k9-c1',
#   'layers.21',
#   'layers.22'],
#  '15': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'k11-c0',
#   'k11-c0',
#   'k9-c1',
#   'k9-c1',
#   'layers.21',
#   'layers.22'],
#  '16': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'layers.17',
#   'layers.18',
#   'k9-c1',
#   'k9-c1',
#   'layers.21',
#   'layers.22'],
#  '17': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'k8-c1',
#   'k8-c1',
#   'k10-c0',
#   'k10-c0',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'layers.17',
#   'layers.18',
#   'layers.19',
#   'layers.20',
#   'layers.21',
#   'layers.22'],
#  '18': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'k8-c1',
#   'k8-c1',
#   'layers.7',
#   'layers.8',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'layers.17',
#   'layers.18',
#   'layers.19',
#   'layers.20',
#   'layers.21',
#   'layers.22'],
#  '19': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'layers.5',
#   'layers.6',
#   'layers.7',
#   'layers.8',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'k12-c0',
#   'k12-c0',
#   'layers.16',
#   'layers.17',
#   'layers.18',
#   'layers.19',
#   'layers.20',
#   'layers.21',
#   'layers.22'],
#  '20': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'layers.5',
#   'layers.6',
#   'layers.7',
#   'layers.8',
#   'k10-c1',
#   'k10-c1',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'layers.14',
#   'layers.15',
#   'layers.16',
#   'layers.17',
#   'layers.18',
#   'layers.19',
#   'layers.20',
#   'layers.21',
#   'layers.22'],
#  '21': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'layers.5',
#   'layers.6',
#   'layers.7',
#   'layers.8',
#   'layers.9',
#   'layers.10',
#   'k7-c1',
#   'k7-c1',
#   'layers.13',
#   'layers.14',
#   'layers.15',
#   'layers.16',
#   'layers.17',
#   'layers.18',
#   'layers.19',
#   'layers.20',
#   'layers.21',
#   'layers.22'],
#  '22': ['layers.0',
#   'k13-c0',
#   'k13-c0',
#   'layers.3',
#   'layers.4',
#   'layers.5',
#   'layers.6',
#   'layers.7',
#   'layers.8',
#   'layers.9',
#   'layers.10',
#   'layers.11',
#   'layers.12',
#   'layers.13',
#   'layers.14',
#   'layers.15',
#   'layers.16',
#   'layers.17',
#   'layers.18',
#   'layers.19',
#   'layers.20',
#   'layers.21',
#   'layers.22']}
